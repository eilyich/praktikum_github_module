# %% [markdown]
# # Анализ оттока клиентов
# В рамках данного проекта разработаем модель прогнозирования оттока клиентов "Бета-Банка". Фактом оттока считается расторжение договора предоставления банковских услуг клинетом. Целевая метрика f1 (совместная оценка точности и полноты прогноза) - не ниже **0.59**

# %% [markdown]
# #### Оглавление<a id="0"></a>
#
# - [Загрузка данных](#1)
#     - [Обзор данных](#1.1)
# - [Подготовка данных](#2)
# - [Обучение](#3)
#     - [Работа с "сырыми" моделями](#3.1)
#     - [Устранение дисбаланса](#3.2)
#     - [Подбор гипер-параметров](#3.3)
#         - [Logistic Regression](#3.3.1)
#         - [Decision Tree](#3.3.2)
#         - [Random Forest](#3.3.3)
#     - [Сравнение ROC AUC](#3.4)
# - [Тестирование](#4)
# - [Заключение](#5)

# %% [markdown]
# В нашем распоряжении выборка данных о 10 тысячах клиентов. Таблица содержит следующие столбцы:
#
# Административные данные:
# - `RowNumber` — индекс строки в данных
# - `CustomerId` — уникальный идентификатор клиента
# - `Surname` — фамилия
#
# Признаки:
# - `CreditScore` — кредитный рейтинг
# - `Geography` — страна проживания
# - `Gender` — пол
# - `Age` — возраст
# - `Tenure` — сколько лет человек является клиентом банка
# - `Balance` — баланс на счёте
# - `NumOfProducts` — количество продуктов банка, используемых клиентом
# - `HasCrCard` — наличие кредитной карты
# - `IsActiveMember` — активность клиента
# - `EstimatedSalary` — предполагаемая зарплата
#
#
# Целевой признак:
# - `Exited` — факт ухода клиента
#
# Подготовим необходимые для работы библиотеки и установим настройки.

# %%
# %%capture
#!pip install -U tqdm
# !pip install -U seaborn

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

import optuna

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale = 1.1, style='darkgrid')

from tqdm import tqdm
import operator
import warnings
warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False

c = 'Blues' # colormap
rs = 100 # random state

# %% [markdown]
# ### Загрузка и обзор данных<a id="1"></a>
# Загрузим таблицу и изучим её состав.

# %%
df = pd.read_csv('Churn.csv')

display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB
# None
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# <a id="1.1"></a>
#
# Два категориальных признака представлены в строковом формате. Далее мы закодируем их для построения модели прогнозирования.  Также в колонке "Tenure" (длительность пользования услугами) есть пропущенные значения.
#
# Изучим как распределены признаки в датасете (исключим административные колонки и целевой признак).

# %%
data_overview = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])
data_overview['NumOfProducts'] = data_overview['NumOfProducts'].astype('str')
data_overview['HasCrCard'] = data_overview['HasCrCard'].astype('str')
data_overview['IsActiveMember'] = data_overview['IsActiveMember'].astype('str')
grid =  [(i, j) for i in range(5) for j in range(2)]

fig, ax = plt.subplots(5, 2, figsize=(14, 22))

for position, column in zip(grid, data_overview):
    sns.histplot(data=data_overview, x=column, ax=ax[position], hue='Exited', legend=False, alpha=.5, palette=c)
    try:
        mean1 = data_overview[data_overview['Exited'] != 1][column].mean()
        mean2 = data_overview[data_overview['Exited'] == 1][column].mean()
        ax[position].axvline(mean1, c='#a1b9cc')
        ax[position].axvline(mean2, c='#59768f')
    except:
        pass

ax[0, 0].legend(['No churned', 'Churned'], loc=2, fancybox=True)

plt.suptitle('Распределение признаков для действительных клиентов и клиентов в оттоке', fontsize=20, y=.99)
plt.tight_layout()
plt.show()
plt.close()

# %% [markdown]
# Наибольшая разница средних значений между клиентами попаышими в отток и оставшимися наблюдается в категориях "Balance" (баланс счёта) и "Age" (возраст). Также образщает на себя внимание, что доля оттока среди клиентов, пользующихся двумя услугами меньше, чем одной услугой (при том, что общее количество пользователей двух услуг больше). Также доля ушедших клиентов в Германии больше, чем, например, в Испании.
#
# Проверим корреляции между признаками.

# %%
data_correlations = df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])
encoded_columns = OrdinalEncoder().fit_transform(df[['Geography', 'Gender']])
data_correlations['Geography'] = encoded_columns[:, 0]
data_correlations['Gender'] = encoded_columns[:, 1]

plt.figure(figsize=(8, 8))

corr = data_correlations.corr()
mask = np.triu(np.ones_like(corr, dtype='bool'))

ax = sns.heatmap(corr, linewidths=2, annot=True, mask=mask,
                 annot_kws={'size': 10}, fmt='.2f', vmin=-.4,  vmax=.4, cmap=c)
ax.invert_xaxis()
ax.xaxis.get_ticklabels()[10].set_color('r')
ax.yaxis.get_ticklabels()[10].set_color('r')

plt.title('Корреляция признаков', fontsize=14)
plt.show()
plt.close()

# %% [markdown]
# Целевой признак оттока слабо коррелирует с возрастом клиентов. Однако, наблюдемый коэффициент корреляции недостаточен, чтобы считать отток связанным с возрастом.
#
#
#
#
# - [К оглавлению](#0)

# %% [markdown]
# ### Подготовка данных<a id="2"></a>
# Выберем признаки, на основе которых будем проводить исследование. В колонке "Tenure" (длительность пользования услугами) заменим отсутствующие значения на `-1`

# %%
Xy_raw = df.loc[:, 'CreditScore': 'Exited']
Xy_raw['Tenure'] = Xy_raw['Tenure'].fillna(-1)

# %% [markdown]
# Так как колонки 'Geography' и 'Gender' содержат категориальные значения, преобразуем их методом прямого кодирования в бинарные значения.

# %%
Xy_raw = Xy_raw.join(pd.get_dummies(Xy_raw[['Geography', 'Gender']], drop_first=True)).drop(columns={'Geography', 'Gender'})

# %% [markdown]
# Разделим выборку на обучающую, валидационную и тестовую в пропорциях 3/1/1, и проверим размерность получившихся наборов данных.

# %%
split_20_percent = int(len(Xy_raw) * .2)
test, val, train = np.split(Xy_raw.sample(frac=1, random_state=rs), [split_20_percent, split_20_percent * 2])

ex = 'Exited'
X_train = train.drop(columns={ex})
X_val = val.drop(columns={ex})
X_test = test.drop(columns={ex})
y_train = train[ex]
y_test = test[ex]
y_val = val[ex]

print('Размер подвыборок:')
display(X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_test.shape, y_val.shape)
# Out:
# Размер подвыборок:
# (6000, 11)
# (2000, 11)
# (2000, 11)
# (6000,)
# (2000,)
# (2000,)

# %% [markdown]
# Cтандартизируем численные признаки и проверим результат.

# %%
standart_columns = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

scaler = StandardScaler()
scaler.fit(X_train[standart_columns])

X_train[standart_columns] = scaler.transform(X_train[standart_columns])
X_val[standart_columns] = scaler.transform(X_val[standart_columns])
X_test[standart_columns] = scaler.transform(X_test[standart_columns])

# %% [markdown]
# Данные стандартизированы. Выборка разделена в нужных пропорциях. Ни один признак не потерялся.
#
#
#
# - [К оглавлению](#0)

# %% [markdown]
# ### Обучение<a id="3"></a>

# %% [markdown]
# #### Работа с сырыми моделями и данными<a id="3.1"></a>
# Напишем функции для обучения, предсказания и измерения f1 для трёх моделей: Логистической регрессии, Дерева решений и Случайного леса.

# %%
def model_tune(model='RandomForest', X=X_val, y=y_val, X_train=X_train, y_train=y_train,
               nest=100, depth=None, min_leaf=1, threshold=.5):
    if model == 'RandomForest':
        model = RandomForestClassifier( n_estimators=nest, max_depth=depth, random_state=rs )
    if model == 'DecisionTree':
        model = DecisionTreeClassifier( max_depth=depth, min_samples_leaf=min_leaf, random_state=rs )
    if model == 'LogisticRegression':
        model = LogisticRegression( solver='liblinear', random_state=rs )    
        
    model.fit(X_train, y_train)
    y_predict = model.predict(X)
    f1 = f1_score(y, y_predict)    
    proba = model.predict_proba(X)[:, 1]
    corrected_predictions = proba > threshold
    f1_proba = f1_score(y, corrected_predictions)      
    
    
    return {'predictions': y_predict, 'probabilities': proba,
            'corrected_predictions': corrected_predictions,
            'f1': f1, 'f1_corrected':  f1_proba}

# %%
print(f"f1 модели:  {model_tune('LogisticRegression')['f1']}")
# Out:
# f1 модели:  0.33212996389891697

# %%
print(f"f1 модели:  {model_tune('DecisionTree')['f1']}")
# Out:
# f1 модели:  0.5245901639344261

# %%
print(f"f1 модели:  {model_tune('RandomForest')['f1']}")
# Out:
# f1 модели:  0.5934718100890207

# %% [markdown]
# Даже на неподготовленной модели Random Forest метрика f1 близка к целевой.

# %% [markdown]
# #### Устранение дисбаланса<a id="3.2"></a>
# Положительный класс во всей выборке встречается в 4 раза реже:

# %%
Xy_raw['Exited'].value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %% [markdown]
# В такой же пропорции положительный класс распределён в тренировочной выборке:

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.797333
# 1    0.202667
# Name: Exited, dtype: float64

# %% [markdown]
# ##### Upsampling
# Дисбаланс выборки устраним с помощью досемплирования.

# %%
X_0 = X_train[y_train == 0]
X_1 = X_train[y_train == 1]
y_0 = y_train[y_train == 0]
y_1 = y_train[y_train == 1]

repeat = int(y_train.value_counts(normalize=True)[0] / y_train.value_counts(normalize=True)[1])

X_train, y_train = (shuffle(pd.concat([X_0] + [X_1] * repeat),
                            pd.concat([y_0] + [y_1] * repeat), random_state=rs))

# %%
print("Преобразованные данные:")
print(y_train.value_counts(normalize=True))
print(f"{len(y_train)} записей")
# Out:
# Преобразованные данные:
# 0    0.567362
# 1    0.432638
# Name: Exited, dtype: float64
# 8432 записей

# %% [markdown]
# В результате апсемплинга количество записей увеличилось на ~2,5 тысячи. Баланс классов составляет 57/43.

# %% [markdown]
# ##### Downsampling
# Также, в качестве альтернативного метода борьбы с дисбалансом, проведём даунсэмплинг. Эти подвыборки пригодятся позже.

# %%
fraction_coef = len(y_1) / len(y_0)
X_train_d = pd.concat([X_0.sample(frac=fraction_coef, random_state=rs)] + [X_1])
y_train_d = pd.concat([y_0.sample(frac=fraction_coef, random_state=rs)] + [y_1])
X_train_d, y_train_d = shuffle(X_train_d, y_train_d, random_state=rs)

print("Преобразованные данные:")
print(y_train_d.value_counts(normalize=True))
print(f"{len(y_train_d)} записей")
# Out:
# Преобразованные данные:
# 0    0.5
# 1    0.5
# Name: Exited, dtype: float64
# 2432 записей

# %% [markdown]
# - [К оглавлению](#0)

# %% [markdown]
# #### Подбор гиперпараметров на досэмплированной выборке<a id="3.3"></a>
# Выберем и настроим модель на сбалансированных данных.
# Подберем гиперпараметры с помощью **Optuna**.

# %%
def objective(trial): 
    classifier_name = trial.suggest_categorical('classifier', ['LogisticRegression',
                                                               'DecisionTreeClassifier',
                                                               'RandomForestClassifier'])
    if classifier_name == 'LogisticRegression':
        C = trial.suggest_float("C", 1e-6, 10.0, log=True)
        th = trial.suggest_float('th', 0.25, 0.7, log=True)
        model = LogisticRegression(C = C, random_state=rs)
        model.fit(X_train, y_train)
        
    if classifier_name == 'DecisionTreeClassifier':
        min_leaf = trial.suggest_int("min_leaf", 10, 105, log=False)
        depth = trial.suggest_int("depth", 11, 21, 1, log=True)
        th = trial.suggest_float('th', 0.25, 0.7, log=True)
        model = DecisionTreeClassifier(min_samples_leaf = min_leaf, max_depth = depth, random_state=rs)
        model.fit(X_train, y_train)
        
    if classifier_name == 'RandomForestClassifier':
        n_estimators = trial.suggest_int('n_estimators', 80, 110, 10, log=False)
        depth = trial.suggest_int("depth", 11, 21, 1, log=True)
        th = trial.suggest_float('th', 0.25, 0.7, log=True)
        model = RandomForestClassifier(n_estimators=n_estimators, max_depth = depth, random_state=rs)
        model.fit(X_train, y_train)
        
    proba = model.predict_proba(X_val)[:, 1]
    corrected_predictions = proba > th
    f1 = f1_score(y_val, corrected_predictions)

    return f1

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=300)
# Out:
# [I 2022-12-07 18:39:50,651] A new study created in memory with name: no-name-e1a56131-f888-4ac0-adfa-fabf5378c6ea
# [I 2022-12-07 18:39:52,491] Trial 0 finished with value: 0.6206896551724137 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 13, 'th': 0.5355558925285678}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:53,965] Trial 1 finished with value: 0.6203346203346203 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.49206019841215765}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,017] Trial 2 finished with value: 0.5063670411985018 and parameters: {'classifier': 'LogisticRegression', 'C': 0.831497504011486, 'th': 0.3691807959237605}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,069] Trial 3 finished with value: 0.5175953079178885 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 98, 'depth': 12, 'th': 0.2899401601445993}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,129] Trial 4 finished with value: 0.5675430643699003 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 40, 'depth': 14, 'th': 0.400643668928107}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,161] Trial 5 finished with value: 0.38535031847133755 and parameters: {'classifier': 'LogisticRegression', 'C': 0.05512536721840487, 'th': 0.6879224411108096}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,217] Trial 6 finished with value: 0.4992887624466572 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 72, 'depth': 14, 'th': 0.2588536460404459}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,276] Trial 7 finished with value: 0.5356576862123613 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 43, 'depth': 18, 'th': 0.2938770286519366}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:54,309] Trial 8 finished with value: 0.33955998339559984 and parameters: {'classifier': 'LogisticRegression', 'C': 1.5307358846265375e-06, 'th': 0.3401068010635795}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:55,970] Trial 9 finished with value: 0.5940409683426444 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.2977890703377551}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:57,750] Trial 10 finished with value: 0.6151898734177216 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 11, 'th': 0.5256199856647636}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:39:59,223] Trial 11 finished with value: 0.6051948051948052 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 15, 'th': 0.5080640363184863}. Best is trial 0 with value: 0.6206896551724137.
# [I 2022-12-07 18:40:01,332] Trial 12 finished with value: 0.6214099216710183 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 20, 'th': 0.4944048928353567}. Best is trial 12 with value: 0.6214099216710183.
# [I 2022-12-07 18:40:03,422] Trial 13 finished with value: 0.5775075987841946 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 21, 'th': 0.6261287288500254}. Best is trial 12 with value: 0.6214099216710183.
# [I 2022-12-07 18:40:05,515] Trial 14 finished with value: 0.597997138769671 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 21, 'th': 0.5645155486659571}. Best is trial 12 with value: 0.6214099216710183.
# [I 2022-12-07 18:40:07,279] Trial 15 finished with value: 0.6244239631336407 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.4438573019112037}. Best is trial 15 with value: 0.6244239631336407.
# [I 2022-12-07 18:40:09,176] Trial 16 finished with value: 0.6292682926829268 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 19, 'th': 0.44812172303655523}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:11,090] Trial 17 finished with value: 0.6198830409356725 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 18, 'th': 0.42664575325881704}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:12,784] Trial 18 finished with value: 0.6153846153846154 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 12, 'th': 0.43061438421671}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:12,826] Trial 19 finished with value: 0.21468926553672318 and parameters: {'classifier': 'LogisticRegression', 'C': 3.161032653362259e-05, 'th': 0.451980272132643}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:14,543] Trial 20 finished with value: 0.6083244397011741 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 19, 'th': 0.3683961620742604}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:16,447] Trial 21 finished with value: 0.6195786864931846 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 20, 'th': 0.4589485275078543}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:18,317] Trial 22 finished with value: 0.5894428152492669 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 16, 'th': 0.5928165530529783}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:20,032] Trial 23 finished with value: 0.6198243412797992 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 19, 'th': 0.46913271022820563}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:21,731] Trial 24 finished with value: 0.60431654676259 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.38224869288789026}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:23,818] Trial 25 finished with value: 0.6012145748987854 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 17, 'th': 0.32866448535181414}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:25,729] Trial 26 finished with value: 0.6107921928817451 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 20, 'th': 0.4088343759014574}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:27,383] Trial 27 finished with value: 0.6180904522613065 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 15, 'th': 0.48273261948423596}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:27,470] Trial 28 finished with value: 0.5764966740576497 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 12, 'depth': 11, 'th': 0.5589615986462001}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:27,529] Trial 29 finished with value: 0.43360433604336046 and parameters: {'classifier': 'LogisticRegression', 'C': 0.0007643685078517078, 'th': 0.5271836833274661}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:29,521] Trial 30 finished with value: 0.6062717770034843 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 14, 'th': 0.43405428094342063}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:31,456] Trial 31 finished with value: 0.6153846153846154 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 13, 'th': 0.4975235180042921}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:33,424] Trial 32 finished with value: 0.5979680696661829 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 13, 'th': 0.6087522843073204}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:34,849] Trial 33 finished with value: 0.6166007905138339 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 12, 'th': 0.5544778978257267}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:36,941] Trial 34 finished with value: 0.5539906103286385 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 19, 'th': 0.6527274905867978}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:36,987] Trial 35 finished with value: 0.5242334322453017 and parameters: {'classifier': 'LogisticRegression', 'C': 8.731245897377807, 'th': 0.4860779006728863}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:37,068] Trial 36 finished with value: 0.5809954751131222 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 101, 'depth': 16, 'th': 0.39037104751557106}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:38,830] Trial 37 finished with value: 0.6233766233766235 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.5235788788522422}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:40,651] Trial 38 finished with value: 0.6146572104018913 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 14, 'th': 0.4483967840230959}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:40,729] Trial 39 finished with value: 0.560344827586207 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 71, 'depth': 12, 'th': 0.35953886813111935}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:42,640] Trial 40 finished with value: 0.6100917431192661 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 20, 'th': 0.40707259308423915}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:44,423] Trial 41 finished with value: 0.6223958333333334 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.5256700917933065}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:46,182] Trial 42 finished with value: 0.6229086229086228 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.519233589010274}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:47,948] Trial 43 finished with value: 0.6233766233766235 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.5246252951579141}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:49,648] Trial 44 finished with value: 0.6157894736842106 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 12, 'th': 0.5510156626247421}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:49,699] Trial 45 finished with value: 0.4871194379391101 and parameters: {'classifier': 'LogisticRegression', 'C': 0.002166425407655865, 'th': 0.5194738247787863}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:51,514] Trial 46 finished with value: 0.5934379457917262 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 14, 'th': 0.5885667509217178}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:53,170] Trial 47 finished with value: 0.5409836065573771 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 15, 'th': 0.693902611723108}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:53,267] Trial 48 finished with value: 0.5748502994011976 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 11, 'depth': 14, 'th': 0.4726026857092603}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:55,020] Trial 49 finished with value: 0.6130653266331658 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.5064013023060696}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:56,645] Trial 50 finished with value: 0.6145374449339207 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 11, 'th': 0.44797402496506467}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:58,396] Trial 51 finished with value: 0.6198675496688741 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.5335631560194998}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:40:59,643] Trial 52 finished with value: 0.5945945945945946 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 14, 'th': 0.5852308681020083}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:00,846] Trial 53 finished with value: 0.575712143928036 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 13, 'th': 0.6395589604117397}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:02,546] Trial 54 finished with value: 0.6163522012578616 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 12, 'th': 0.513216480502906}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:04,250] Trial 55 finished with value: 0.6242197253433208 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.46374090150866876}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:05,990] Trial 56 finished with value: 0.6162927981109799 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.4230122443423052}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:06,036] Trial 57 finished with value: 0.522232734153264 and parameters: {'classifier': 'LogisticRegression', 'C': 0.05535449867728434, 'th': 0.46499692003727466}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:07,565] Trial 58 finished with value: 0.6230677764565993 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4382883017671147}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:09,082] Trial 59 finished with value: 0.6155580608793687 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.3946191505332448}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:10,591] Trial 60 finished with value: 0.6189917936694022 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4327081393574641}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:12,093] Trial 61 finished with value: 0.6242038216560509 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.48066052210279153}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:13,586] Trial 62 finished with value: 0.616580310880829 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.48620782315467803}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:15,051] Trial 63 finished with value: 0.6231884057971016 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.4438229406855759}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:16,563] Trial 64 finished with value: 0.6191588785046729 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.4172408540766885}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:18,053] Trial 65 finished with value: 0.6179066834804541 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.47318899856556673}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:19,754] Trial 66 finished with value: 0.6224999999999999 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.4638792394710277}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:19,839] Trial 67 finished with value: 0.5862785862785863 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 35, 'depth': 15, 'th': 0.4978832446437069}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:21,515] Trial 68 finished with value: 0.6153846153846153 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 16, 'th': 0.4487046345418109}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:23,034] Trial 69 finished with value: 0.610917537746806 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 21, 'th': 0.41682331714822335}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:23,084] Trial 70 finished with value: 0.0 and parameters: {'classifier': 'LogisticRegression', 'C': 1.178396215402088e-06, 'th': 0.48042691889287437}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:24,611] Trial 71 finished with value: 0.6200241254523521 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4406408044726838}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:26,132] Trial 72 finished with value: 0.6067172264355363 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.3782515951643309}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:27,624] Trial 73 finished with value: 0.566873339238264 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 16, 'th': 0.27198128891441864}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:29,146] Trial 74 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4572165051409291}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:30,853] Trial 75 finished with value: 0.6113416320885201 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.5448934969963377}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:32,362] Trial 76 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45683543679226074}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:33,897] Trial 77 finished with value: 0.6253229974160207 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.49113998377999296}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:35,407] Trial 78 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46055082698415245}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:36,931] Trial 79 finished with value: 0.6232073011734028 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4959554798591112}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:37,011] Trial 80 finished with value: 0.598825831702544 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 79, 'depth': 19, 'th': 0.4579450848405523}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:38,531] Trial 81 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45972288889524615}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:40,040] Trial 82 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4582993216838001}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:41,576] Trial 83 finished with value: 0.617283950617284 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.4584134761093158}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:43,100] Trial 84 finished with value: 0.6182669789227166 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4311449668521042}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:44,619] Trial 85 finished with value: 0.6146788990825688 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4107470036126744}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:46,156] Trial 86 finished with value: 0.6224999999999999 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4672402258107791}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:47,734] Trial 87 finished with value: 0.6024636058230682 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.3994741733200068}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:47,781] Trial 88 finished with value: 0.0 and parameters: {'classifier': 'LogisticRegression', 'C': 5.1530623452751505e-05, 'th': 0.503006126164818}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:49,297] Trial 89 finished with value: 0.6141367323290845 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4221736454581203}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:50,822] Trial 90 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4529539860599533}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:52,353] Trial 91 finished with value: 0.6175349428208388 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.47558007501669486}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:53,882] Trial 92 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45726048937553454}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:55,411] Trial 93 finished with value: 0.6245443499392467 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44978018761485367}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:56,944] Trial 94 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4556223117368126}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:41:58,476] Trial 95 finished with value: 0.6161745827984596 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.48938414169692884}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:00,004] Trial 96 finished with value: 0.6144721233689204 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 21, 'th': 0.4300808914371911}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:01,068] Trial 97 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.4554851588642706}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:02,577] Trial 98 finished with value: 0.6195524146054182 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4357387527671598}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:04,095] Trial 99 finished with value: 0.6178489702517163 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4079378450527582}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:04,150] Trial 100 finished with value: 0.6015625 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 57, 'depth': 20, 'th': 0.4727610128824988}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:05,207] Trial 101 finished with value: 0.6237864077669903 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4485032640717518}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:06,242] Trial 102 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4542828897241136}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:07,294] Trial 103 finished with value: 0.6253229974160207 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4909970624379083}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:08,325] Trial 104 finished with value: 0.6147757255936676 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.5088371300373901}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:09,844] Trial 105 finished with value: 0.6224366706875755 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.44026528981536084}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:11,372] Trial 106 finished with value: 0.6246913580246913 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4617003900545381}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:12,891] Trial 107 finished with value: 0.6243654822335026 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.47840652500802133}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:14,424] Trial 108 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4554594571995984}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:14,483] Trial 109 finished with value: 0.5167958656330749 and parameters: {'classifier': 'LogisticRegression', 'C': 0.06174004468822736, 'th': 0.42494010793348136}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:16,011] Trial 110 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.4536427245375779}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:17,541] Trial 111 finished with value: 0.6192771084337348 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.439248918321457}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:19,076] Trial 112 finished with value: 0.6206896551724137 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.48516934224285096}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:20,592] Trial 113 finished with value: 0.6251556662515567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4708348722067697}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:22,125] Trial 114 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.454253879973613}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:23,641] Trial 115 finished with value: 0.6155778894472362 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.46515412799332984}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:25,173] Trial 116 finished with value: 0.6215235792019347 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44211110723442393}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:26,708] Trial 117 finished with value: 0.6105990783410138 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.41341524333538315}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:28,211] Trial 118 finished with value: 0.6192170818505338 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.42804370538538833}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:29,753] Trial 119 finished with value: 0.6176084099868594 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.5009424813838618}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:29,831] Trial 120 finished with value: 0.5520833333333333 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 25, 'depth': 18, 'th': 0.4805869282915093}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:31,363] Trial 121 finished with value: 0.6245161290322581 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.49045623004839944}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:32,890] Trial 122 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4654265309663282}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:34,411] Trial 123 finished with value: 0.6285018270401949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45563057954611025}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:35,933] Trial 124 finished with value: 0.6205191594561186 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.45474132414039276}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:37,463] Trial 125 finished with value: 0.6021093000958773 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.3109049014280021}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:38,507] Trial 126 finished with value: 0.6251497005988024 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4472900599950938}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:39,549] Trial 127 finished with value: 0.6213836477987422 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4735777496620467}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:41,065] Trial 128 finished with value: 0.6211764705882352 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.43515475481998506}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:42,593] Trial 129 finished with value: 0.6098130841121495 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.42099748240534135}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:44,107] Trial 130 finished with value: 0.6169154228855722 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.45988536706532857}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:45,627] Trial 131 finished with value: 0.6245161290322581 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.48907733690618765}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:47,140] Trial 132 finished with value: 0.6260454002389486 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4451726999162894}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:48,659] Trial 133 finished with value: 0.6251497005988024 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.44847000927304836}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:50,175] Trial 134 finished with value: 0.6224999999999999 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4684686501187943}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:51,693] Trial 135 finished with value: 0.6260454002389486 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.44252607602456595}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:51,753] Trial 136 finished with value: 0.5100671140939597 and parameters: {'classifier': 'LogisticRegression', 'C': 0.0002055585890006248, 'th': 0.42990327510258947}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:53,277] Trial 137 finished with value: 0.618531889290012 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 21, 'th': 0.4454463389519342}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:54,778] Trial 138 finished with value: 0.6238095238095237 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4392843375634744}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:56,310] Trial 139 finished with value: 0.6280788177339901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4597098725942655}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:57,840] Trial 140 finished with value: 0.6280788177339901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.460304223620293}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:42:59,371] Trial 141 finished with value: 0.6263871763255241 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4609181369633813}. Best is trial 16 with value: 0.6292682926829268.
# [I 2022-12-07 18:43:00,895] Trial 142 finished with value: 0.6297662976629766 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4576250420032003}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:02,422] Trial 143 finished with value: 0.6183206106870229 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.47780135131347423}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:03,956] Trial 144 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.4578723211972745}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:05,474] Trial 145 finished with value: 0.6240601503759399 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4709649962898647}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:07,006] Trial 146 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45598151428529876}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:08,543] Trial 147 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.45359143585371087}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:08,613] Trial 148 finished with value: 0.5876685934489404 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 86, 'depth': 19, 'th': 0.4650321258020895}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:10,153] Trial 149 finished with value: 0.6254458977407847 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4334133912990788}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:11,597] Trial 150 finished with value: 0.6130177514792899 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 110, 'depth': 20, 'th': 0.42180524247190465}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:12,636] Trial 151 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45313054580935785}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:14,159] Trial 152 finished with value: 0.6175349428208388 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4755592005020827}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:15,202] Trial 153 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4532121000290579}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:16,738] Trial 154 finished with value: 0.616751269035533 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.480990688057411}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:18,273] Trial 155 finished with value: 0.6238095238095237 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4371287466647747}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:19,804] Trial 156 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46088838652102543}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:21,335] Trial 157 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45229398202662163}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:22,871] Trial 158 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.466377842357925}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:24,404] Trial 159 finished with value: 0.6115702479338843 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.42837483520259223}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:24,464] Trial 160 finished with value: 0.5243088655862728 and parameters: {'classifier': 'LogisticRegression', 'C': 5.5808504786225965, 'th': 0.47013962552548516}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:25,989] Trial 161 finished with value: 0.6230303030303029 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4482371630175789}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:27,521] Trial 162 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4541577824472005}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:29,060] Trial 163 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.453199724167486}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:30,591] Trial 164 finished with value: 0.6222760290556901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44386684087913036}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:32,140] Trial 165 finished with value: 0.6280788177339901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.459108465434665}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:33,676] Trial 166 finished with value: 0.616751269035533 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.47942514925471236}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:35,205] Trial 167 finished with value: 0.6270136307311028 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46366618485503736}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:36,740] Trial 168 finished with value: 0.6238095238095237 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.43673267935855503}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:38,459] Trial 169 finished with value: 0.6139896373056996 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 19, 'th': 0.4979926028169153}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:39,987] Trial 170 finished with value: 0.6263871763255241 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.46048361294081985}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:41,524] Trial 171 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45448976166197524}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:43,057] Trial 172 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.47198347614968117}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:44,590] Trial 173 finished with value: 0.6222760290556901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44290067514279174}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:46,121] Trial 174 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45444704566819716}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:47,657] Trial 175 finished with value: 0.6183206106870229 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4820450150332667}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:49,189] Trial 176 finished with value: 0.6135552913198573 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.4338991939779768}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:50,722] Trial 177 finished with value: 0.6245443499392467 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44975853354694273}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:52,254] Trial 178 finished with value: 0.6297662976629766 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4574705649393971}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:52,344] Trial 179 finished with value: 0.496113074204947 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 56, 'depth': 20, 'th': 0.25122829974061406}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:53,863] Trial 180 finished with value: 0.6224999999999999 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.46699737985835016}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:55,404] Trial 181 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4547635195655546}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:56,943] Trial 182 finished with value: 0.6297662976629766 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4578952143605987}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:43:58,469] Trial 183 finished with value: 0.6222760290556901 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44473667212855184}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:00,005] Trial 184 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4664817826949563}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:01,537] Trial 185 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4557908436567589}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:03,087] Trial 186 finished with value: 0.6272189349112426 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4273664463444022}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:04,604] Trial 187 finished with value: 0.6202830188679246 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.43728219202256957}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:06,137] Trial 188 finished with value: 0.6230303030303029 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4463248170798304}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:07,671] Trial 189 finished with value: 0.6159695817490495 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.47644107925811974}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:09,201] Trial 190 finished with value: 0.6235565819861432 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.41733080115889193}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:10,735] Trial 191 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4526126751247976}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:12,277] Trial 192 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45711853969321437}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:13,809] Trial 193 finished with value: 0.628992628992629 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4568136564884855}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:15,338] Trial 194 finished with value: 0.6224999999999999 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4696920638506358}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:16,870] Trial 195 finished with value: 0.6192771084337348 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4394327329011642}. Best is trial 142 with value: 0.6297662976629766.
# [I 2022-12-07 18:44:18,303] Trial 196 finished with value: 0.629404617253949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45415539404687844}. Best is trial 142 with value: 0.6297662976629766.
# ...
# [I 2022-12-07 18:45:21,048] Trial 238 finished with value: 0.5227906976744185 and parameters: {'classifier': 'LogisticRegression', 'C': 0.623372157886495, 'th': 0.45758464188839837}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:22,571] Trial 239 finished with value: 0.6260454002389486 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.44518387357529304}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:23,616] Trial 240 finished with value: 0.623574144486692 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.476736414389764}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:25,136] Trial 241 finished with value: 0.626829268292683 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4560968974463279}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:26,668] Trial 242 finished with value: 0.6278787878787878 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45123614105848014}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:28,190] Trial 243 finished with value: 0.6155778894472362 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.465201041344929}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:29,711] Trial 244 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45670135610731294}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:31,219] Trial 245 finished with value: 0.6189917936694022 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4334684669915594}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:32,740] Trial 246 finished with value: 0.6251497005988024 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4461821525554779}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:34,268] Trial 247 finished with value: 0.6270136307311028 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4626215171358237}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:35,787] Trial 248 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4727167458507409}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:37,315] Trial 249 finished with value: 0.629404617253949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4545054683234708}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:38,835] Trial 250 finished with value: 0.6260454002389486 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.44418944937634464}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:40,367] Trial 251 finished with value: 0.629404617253949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45241900566220794}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:42,267] Trial 252 finished with value: 0.6190476190476191 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 18, 'th': 0.4381525070800566}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:43,754] Trial 253 finished with value: 0.6162790697674418 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 15, 'th': 0.42677410874728966}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:45,267] Trial 254 finished with value: 0.6161369193154034 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.4485203164696832}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:46,791] Trial 255 finished with value: 0.6253101736972705 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46475125614568}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:46,875] Trial 256 finished with value: 0.5906432748538012 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 91, 'depth': 18, 'th': 0.4823428226160101}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:48,418] Trial 257 finished with value: 0.6274509803921567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45221071662618434}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:49,935] Trial 258 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.47231017809699316}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:51,464] Trial 259 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4580617715389622}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:52,521] Trial 260 finished with value: 0.6200241254523521 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.44040899451473126}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:53,594] Trial 261 finished with value: 0.6260869565217392 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46577387869432074}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:54,648] Trial 262 finished with value: 0.6266829865361078 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.45005700387595404}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:56,570] Trial 263 finished with value: 0.6279357231149567 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 19, 'th': 0.45798347871352074}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:58,076] Trial 264 finished with value: 0.6182669789227166 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4317602135864997}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:58,125] Trial 265 finished with value: 0.30220713073005095 and parameters: {'classifier': 'LogisticRegression', 'C': 1.9878515916497896e-05, 'th': 0.4429487805489816}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:45:59,584] Trial 266 finished with value: 0.6285018270401949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4555656507529327}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:00,672] Trial 267 finished with value: 0.6183206106870229 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4760886172299963}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:02,199] Trial 268 finished with value: 0.628361858190709 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4571993420401827}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:03,720] Trial 269 finished with value: 0.6260869565217392 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4679928157090229}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:05,361] Trial 270 finished with value: 0.6258992805755396 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 19, 'th': 0.4365724289491804}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:06,892] Trial 271 finished with value: 0.6230303030303029 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.446541743999809}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:08,422] Trial 272 finished with value: 0.6257982120051087 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4827633258863549}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:09,734] Trial 273 finished with value: 0.629404617253949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.454607027947302}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:10,917] Trial 274 finished with value: 0.6227106227106227 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 90, 'depth': 17, 'th': 0.447925392603175}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:12,443] Trial 275 finished with value: 0.6253101736972705 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46436747241536525}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:13,982] Trial 276 finished with value: 0.6153846153846153 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.5125366619317813}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:15,531] Trial 277 finished with value: 0.629404617253949 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.45353864730414134}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:17,077] Trial 278 finished with value: 0.6272189349112426 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4280146452804057}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:17,167] Trial 279 finished with value: 0.5200302343159485 and parameters: {'classifier': 'DecisionTreeClassifier', 'min_leaf': 50, 'depth': 19, 'th': 0.27900639549618356}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:18,612] Trial 280 finished with value: 0.6195524146054182 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4364635113961213}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:20,152] Trial 281 finished with value: 0.6266829865361078 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4509259445240602}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:21,681] Trial 282 finished with value: 0.6260869565217392 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46815142345965755}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:23,204] Trial 283 finished with value: 0.6178266178266179 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.448109644666104}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:24,657] Trial 284 finished with value: 0.6157635467980295 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 14, 'th': 0.4741774686447935}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:26,187] Trial 285 finished with value: 0.6134259259259259 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.42049215337687257}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:27,715] Trial 286 finished with value: 0.6240208877284594 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4973955498536036}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:29,238] Trial 287 finished with value: 0.6200241254523521 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4404444114936106}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:29,291] Trial 288 finished with value: 0.5218198700092851 and parameters: {'classifier': 'LogisticRegression', 'C': 0.009861940973995762, 'th': 0.4539763629438691}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:30,832] Trial 289 finished with value: 0.6270136307311028 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.46370020256163474}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:32,356] Trial 290 finished with value: 0.6282208588957056 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4539355156250838}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:33,890] Trial 291 finished with value: 0.6260454002389486 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4424843588751939}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:35,429] Trial 292 finished with value: 0.6198979591836734 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.48439182760060234}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:36,987] Trial 293 finished with value: 0.6144721233689204 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 21, 'th': 0.43215233475159764}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:38,393] Trial 294 finished with value: 0.6222222222222222 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 18, 'th': 0.46264557747900914}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:39,922] Trial 295 finished with value: 0.6217228464419476 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 18, 'th': 0.4737259113046355}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:41,470] Trial 296 finished with value: 0.6189889025893958 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 20, 'th': 0.45733158543856883}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:43,007] Trial 297 finished with value: 0.6230303030303029 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.4464529623495964}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:44,527] Trial 298 finished with value: 0.6155778894472362 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 17, 'th': 0.4654836454140169}. Best is trial 197 with value: 0.6325224071702945.
# [I 2022-12-07 18:46:46,055] Trial 299 finished with value: 0.5954415954415955 and parameters: {'classifier': 'RandomForestClassifier', 'n_estimators': 80, 'depth': 19, 'th': 0.5720806144518248}. Best is trial 197 with value: 0.6325224071702945.
# FrozenTrial(number=197, values=[0.6325224071702945], datetime_start=datetime.datetime(2022, 12, 7, 18, 44, 18, 303286), datetime_complete=datetime.datetime(2022, 12, 7, 18, 44, 20, 196491), params={'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 18, 'th': 0.4852497757390045}, distributions={'classifier': CategoricalDistribution(choices=('LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier')), 'n_estimators': IntDistribution(high=110, log=False, low=80, step=10), 'depth': IntDistribution(high=21, log=True, low=11, step=1), 'th': FloatDistribution(high=0.7, log=True, low=0.25, step=None)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=197, state=TrialState.COMPLETE, value=None)

# %%
print(study.best_trial.values[0])
print(study.best_trial.params)
# Out:
# 0.6325224071702945
# {'classifier': 'RandomForestClassifier', 'n_estimators': 100, 'depth': 18, 'th': 0.4852497757390045}

# %% [markdown]
# Наибольший f1 `0.63` достигается в модели RandomForestClassifier при гиперпараметрах `depth=18`, `n_estimators=100` и `пороге_классификации=0.48`

# %% [markdown]
# #### подбор гиперпараметров на недосэмплированной выборке
# Посмотрим как будут отличаться результаты при обучении на недосэмплированной выборке.

# %% [markdown]
# ##### Logistic Regression

# %%
logreg_plot_data = {i: model_tune('LogisticRegression', threshold=i,
                                  X_train=X_train_d, y_train=y_train_d)['f1_corrected'] for i in np.arange(0, 0.65, 0.025)}

# %%
fig, ax = plt.subplots(figsize=(16, 8))

ax = sns.lineplot(x=logreg_plot_data.keys(), y=logreg_plot_data.values())
best_threshold = max(logreg_plot_data.items(), key=operator.itemgetter(1))

plt.axvline(.5, ls=':')
plt.axvline(best_threshold[0], c='r')
plt.xlabel('probability threshold')
plt.ylabel('f1 score')
plt.legend(['f1', 'default threshold', 'best threshold'])
plt.show()
plt.close()
print(f"Лучший f1 score {best_threshold[1]:.3f} при пороге {best_threshold[0]:.3f}")

# %% [markdown]
# ##### Decision Tree Classifier

# %%
dec_tree_min_leaf = []
dec_tree_depth = []
dec_tree_threshold = []
dec_tree_f1 = []

for leafs in tqdm(range(10, 105, 5)):
    for depth in range(1, 21):
        for threshold in np.arange(0.2, 0.825, 0.025):
            dec_tree_min_leaf.append(leafs)
            dec_tree_depth.append(depth)
            dec_tree_threshold.append(threshold)
            dec_tree_f1.append(model_tune('DecisionTree', X_train=X_train_d, y_train=y_train_d, min_leaf=leafs,
                                          depth=depth, threshold=threshold)['f1_corrected'])

# %%
dec_tree_data_d = pd.DataFrame({'min_leaf': dec_tree_min_leaf, 'depth': dec_tree_depth,
                              'threshold': dec_tree_threshold, 'f1': dec_tree_f1}).sort_values(by='f1', ascending=False)

dec_tree_data_d.head(10).style.apply(lambda x:
                                   ['background-color: orange'] * 4
                                   if x['f1'] == dec_tree_data_d['f1'].max()
                                   else None, axis=1)

# %% [markdown]
# ##### Random Forest Classifier

# %%
rnd_forest_nest = []
rnd_forest_depth = []
rnd_forest_threshold = []
rnd_forest_f1 = []

for nest in tqdm(range(10, 151, 10)):
    for depth in range(1, 21):
        for threshold in np.arange(0.2, 0.825, 0.025):
            rnd_forest_nest.append(nest)
            rnd_forest_depth.append(depth)
            rnd_forest_threshold.append(threshold)
            rnd_forest_f1.append(model_tune('RandomForest', X_train=X_train_d, y_train=y_train_d, nest=nest,
                                          depth=depth, threshold=threshold)['f1_corrected'])

# %%
rnd_forest_data_d = pd.DataFrame({'n_estimators': rnd_forest_nest, 'depth': rnd_forest_depth,
                              'threshold': rnd_forest_threshold, 'f1': rnd_forest_f1}).sort_values(by='f1', ascending=False)

rnd_forest_data_d.head(10).style.apply(lambda x:
                                    ['background-color: orange'] * 4
                                    if x['f1'] == rnd_forest_data_d['f1'].max()
                                    else None, axis=1)

# %% [markdown]
# #### ROC AUC для досэмплированной выборки<a id="3.4"></a>
# Дополнительно сравним ROC и подсчитаем площадь под кривыми функций для каждой модели на досэмплированной и недосэмплированной выборках.

# %%
logreg_probabilities = model_tune('LogisticRegression')['probabilities']
dec_tree_probabilities = model_tune('DecisionTree',
                                    min_leaf=dec_tree_data['min_leaf'].head(1).item(),
                                    depth=dec_tree_data['depth'].head(1).item())['probabilities']
rnd_forest_probabilities = model_tune('RandomForest',
                                      nest=rnd_forest_data['n_estimators'].head(1).item(),
                                    depth=rnd_forest_data['depth'].head(1).item())['probabilities']

fpr1, tpr1, thresholds1 = roc_curve(y_val, logreg_probabilities)
fpr2, tpr2, thresholds2 = roc_curve(y_val, dec_tree_probabilities)
fpr3, tpr3, thresholds3 = roc_curve(y_val, rnd_forest_probabilities)

fig, ax = plt.subplots(figsize=(14, 8))

ax1 = sns.lineplot(x=fpr1, y=tpr1)
ax2 = sns.lineplot(x=fpr2, y=tpr2)
ax3 = sns.lineplot(x=fpr3, y=tpr3)
ax4 = sns.lineplot([0, 1], linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curves')

plt.legend(['Logistic Regression', 'Decision Tree', 'Random Forest', 'Dummie Model'], loc='lower right')

plt.text(0.22, 0.5, f"LogRegression AUC: {roc_auc_score(y_val, logreg_probabilities):.3f}",
         color=ax.get_lines()[0].get_c())
plt.arrow(0.23, 0.53, -0.037, 0.037, color=ax.get_lines()[0].get_c())

plt.text(0.35, 0.75, f"DecTree AUC: {roc_auc_score(y_val, dec_tree_probabilities):.3f}",
         color=ax.get_lines()[1].get_c())
plt.arrow(0.35, 0.78, -0.037, 0.037, color=ax.get_lines()[1].get_c())

plt.text(0.1, 0.9, f"RndForest AUC: {roc_auc_score(y_val, rnd_forest_probabilities):.3f}",
         color=ax.get_lines()[2].get_c())
plt.arrow(0.22, 0.88, 0.037, -0.037, color=ax.get_lines()[2].get_c())

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [78], line 3
#       1 logreg_probabilities = model_tune('LogisticRegression')['probabilities']
#       2 dec_tree_probabilities = model_tune('DecisionTree',
# ----> 3                                     min_leaf=dec_tree_data['min_leaf'].head(1).item(),
#       4                                     depth=dec_tree_data['depth'].head(1).item())['probabilities']
#       5 rnd_forest_probabilities = model_tune('RandomForest',
#       6                                       nest=rnd_forest_data['n_estimators'].head(1).item(),
#       7                                     depth=rnd_forest_data['depth'].head(1).item())['probabilities']
#       9 fpr1, tpr1, thresholds1 = roc_curve(y_val, logreg_probabilities)
#
# NameError: name 'dec_tree_data' is not defined

# %% [markdown]
# #### ROC AUC для недосэмплированной выборки

# %%
logreg_probabilities = model_tune('LogisticRegression', X_train=X_train_d, y_train=y_train_d)['probabilities']
dec_tree_probabilities = model_tune('DecisionTree',  X_train=X_train_d, y_train=y_train_d,
                                    min_leaf=dec_tree_data_d['min_leaf'].head(1).item(),
                                    depth=dec_tree_data_d['depth'].head(1).item())['probabilities']
rnd_forest_probabilities = model_tune('RandomForest',  X_train=X_train_d, y_train=y_train_d,
                                      nest=rnd_forest_data_d['n_estimators'].head(1).item(),
                                    depth=rnd_forest_data_d['depth'].head(1).item())['probabilities']

fpr1, tpr1, thresholds1 = roc_curve(y_val, logreg_probabilities)
fpr2, tpr2, thresholds2 = roc_curve(y_val, dec_tree_probabilities)
fpr3, tpr3, thresholds3 = roc_curve(y_val, rnd_forest_probabilities)

fig, ax = plt.subplots(figsize=(14, 8))

ax1 = sns.lineplot(x=fpr1, y=tpr1)
ax2 = sns.lineplot(x=fpr2, y=tpr2)
ax3 = sns.lineplot(x=fpr3, y=tpr3)
ax4 = sns.lineplot([0, 1], linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.title('ROC curves')

plt.legend(['Logistic Regression', 'Decision Tree', 'Random Forest', 'Dummie Model'], loc='lower right')

plt.text(0.22, 0.5, f"LogRegression AUC: {roc_auc_score(y_val, logreg_probabilities):.3f}",
         color=ax.get_lines()[0].get_c())
plt.arrow(0.23, 0.53, -0.037, 0.037, color=ax.get_lines()[0].get_c())

plt.text(0.35, 0.75, f"DecTree AUC: {roc_auc_score(y_val, dec_tree_probabilities):.3f}",
         color=ax.get_lines()[1].get_c())
plt.arrow(0.35, 0.78, -0.037, 0.037, color=ax.get_lines()[1].get_c())

plt.text(0.1, 0.9, f"RndForest AUC: {roc_auc_score(y_val, rnd_forest_probabilities):.3f}",
         color=ax.get_lines()[2].get_c())
plt.arrow(0.22, 0.88, 0.037, -0.037, color=ax.get_lines()[2].get_c())

plt.show()
plt.close()

# %% [markdown]
# Модели `DecisionTreeClassifier` и `RandomForestClassifier` с лучшими подобранными гиперпараметрами имеют схожий коэфициент ROC. Однако, Decision Tree уступает при понижении порога принятия положительного класса за счёт более быстрого роста количества ложно-позитивных ответов.
#
# Основываясь на результатах проверки ROC и f1 выберем для дальнейшей работы модель `RandomForestClassifier`, обученную на upsamplied выборке.
#
#
#
# - [К оглавлению](#0)

# %% [markdown]
# ### Тестирование<a id="4"></a>
# Проверим результат работы модели случайного леса с выбранными гиперпараметрами на тестовой выборке.

# %%
test_results = model_tune( model='RandomForest', X=X_test, y=y_test,
                           nest=rnd_forest_data['n_estimators'].head(1).item(),
                           depth=rnd_forest_data['depth'].head(1).item(),
                           threshold=rnd_forest_data['threshold'].head(1).item() )

# %%
plt.figure(figsize=(4, 4))

ax = sns.heatmap(confusion_matrix(y_test, test_results['corrected_predictions']),
                 linewidths=10, annot=True, 
                 annot_kws={'size': 10}, fmt='.0f', cbar=False, cmap=c)

ax.set(xlabel='predictions', ylabel='true answers')

plt.title('Матрица ошибок', fontsize=14)
plt.show()
plt.close()

# %% [markdown]
# На тестовой подвыборке модель верно выявила 224 объекта положительного класса, 101 объект классифицирован ошибочно, 188 положительных объектов не выявлены.

# %%
print(classification_report(y_test, test_results['corrected_predictions']))

# %% [markdown]
# Таким образом, полнота предсказаний положительного класса составляет **0.54**, точность - **0.69**. Сводная метрика f1 - **0,61**, что выше минимального целевого уровня.

# %% [markdown]
# ### Заключение<a id="5"></a>
# Мы выбрали, подготовили и протестировали модель прогнозирования оттока клиентов банка, которая даёт прогноз с точностью и полнотой свыше 60%. При необходимости снизить количество ложных положительных ответов, порог принятия класса можно повысить. При необходимости сместить баланс в пользу максимально выозможной выявляемости положительных ответов порог, напротив, можно понизить.
#
#
# - [К оглавлению](#0)
